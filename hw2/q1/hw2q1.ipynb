# %% [markdown]
# # Homework 2

# %% [markdown]
# ## Question 1

# %%
# Importing the required Keras modules containing model and layers
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D ## only dense is needed ?

# Importing MNIST dataset
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# Reshaping the array to 4-dims so that it can work with the Keras API
# train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
# test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)
# input_shape = (784)


# Normalizing the RGB codes by dividing it by the max RGB value
train_images = train_images/ 255.0
test_images = test_images / 255.0




# create the model and layers
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))

# input_shape = train_images[0].flatten('F')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.2632 - acc: 0.9248 - val_loss: 0.1385 - val_acc: 0.9608
# Epoch 2/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.1155 - acc: 0.9660 - val_loss: 0.1015 - val_acc: 0.9693
# Epoch 3/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0788 - acc: 0.9766 - val_loss: 0.0835 - val_acc: 0.9742
# Epoch 4/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0575 - acc: 0.9832 - val_loss: 0.0812 - val_acc: 0.9772
# Epoch 5/20
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.0443 - acc: 0.9864 - val_loss: 0.0796 - val_acc: 0.9752
# Epoch 6/20
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.0348 - acc: 0.9893 - val_loss: 0.0746 - val_acc: 0.9788
# Epoch 7/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0283 - acc: 0.9916 - val_loss: 0.0746 - val_acc: 0.9780
# Epoch 8/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0225 - acc: 0.9931 - val_loss: 0.0799 - val_acc: 0.9773
# Epoch 9/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0175 - acc: 0.9949 - val_loss: 0.0751 - val_acc: 0.9796
# Epoch 10/20
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0151 - acc: 0.9957 - val_loss: 0.0880 - val_acc: 0.9774
# Epoch 11/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0137 - acc: 0.9956 - val_loss: 0.0892 - val_acc: 0.9770
# Epoch 12/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0100 - acc: 0.9972 - val_loss: 0.0920 - val_acc: 0.9787
# Epoch 13/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0984 - val_acc: 0.9777
# Epoch 14/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0093 - acc: 0.9969 - val_loss: 0.0928 - val_acc: 0.9791
# Epoch 15/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0071 - acc: 0.9979 - val_loss: 0.1027 - val_acc: 0.9768
# Epoch 16/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0083 - acc: 0.9975 - val_loss: 0.1102 - val_acc: 0.9773
# Epoch 17/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0059 - acc: 0.9983 - val_loss: 0.1019 - val_acc: 0.9792
# Epoch 18/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0059 - acc: 0.9983 - val_loss: 0.1110 - val_acc: 0.9786
# Epoch 19/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0065 - acc: 0.9978 - val_loss: 0.1047 - val_acc: 0.9801
# Epoch 20/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0055 - acc: 0.9982 - val_loss: 0.1073 - val_acc: 0.9797

# %% [markdown]
# ## Evaluate accuracy

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 32us/sample - loss: 0.1073 - acc: 0.9797
# Test accuracy: 0.9797

# %% [markdown]
# ## Training/test loss/accuracy during training

# %%
history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

# %%
plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
